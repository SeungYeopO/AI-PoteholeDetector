# %%
# !git clone https://github.com/ultralytics/yolov5

# %% [markdown]
# YOLOv5 Github에서 download

# %%
cd yolov5

# %%
# !pip install -r requirements.txt

# %% [markdown]
# 의존성 패키지 설치

# %%
cd ..

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="RJyesR9bWhJy3glRxhcj")
project = rf.workspace("c106poppy").project("pothole_detection-ogl38")
version = project.version(8)
dataset = version.download("yolov5")

# %% [markdown]
# dataset 다운

# %%
cd yolov5

# %%
# !python train.py --img 480 --batch 4 --epochs 100 --data data.yaml --weights yolov5s.pt

# %% [markdown]
# data.ymal 수정
#
# names:
# - manhole
# - potehole
#
# nc: 2
#
# roboflow:
#   license: CC BY 4.0
#   project: pothole_detection-ogl38
#   url: https://universe.roboflow.com/c106poppy/pothole_detection-ogl38/dataset/8
#   version: 8
#   workspace: c106poppy
#
# path: ../PotHole_detection-8
# test:  test/images
# train: train/images
# val: valid/images

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp6/weights/best.pt --img 640 --conf 0.25 --source /content/sample_data/test.mp4
